# %% [markdown]
# # Introduction

# %% [markdown]
# The National Longitudinal Survey of Youth 1997-2011 dataset is one of the most important databases available to social scientists working with US data.
#
# It allows scientists to look at the determinants of earnings as well as educational attainment and has incredible relevance for government policy. It can also shed light on politically sensitive issues like how different educational attainment and salaries are for people of different ethnicity, sex, and other factors. When we have a better understanding how these variables affect education and earnings we can also formulate more suitable government policies.
#
# <center><img src=https://i.imgur.com/cxBpQ3I.png height=400></center>

# %% [markdown]
# ### Upgrade Plotly

# %%
# %pip install --upgrade plotly

# %% [markdown]
# ###  Import Statements

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Load the Data

# %%
df_data = pd.read_csv('/content/NLSY97_subset.csv')

# %% [markdown]
# ### Understand the Dataset
#
# Have a look at the file entitled `NLSY97_Variable_Names_and_Descriptions.csv`.
#
# ---------------------------
#
#     :Key Variables:
#       1. S           Years of schooling (highest grade completed as of 2011)
#       2. EXP         Total out-of-school work experience (years) as of the 2011 interview.
#       3. EARNINGS    Current hourly earnings in $ reported at the 2011 interview

# %%
df_vnd = pd.read_csv('/content/NLSY97_Variable_Names_and_Descriptions.csv')
df_vnd
# Out:
#     Personal variables  ...                                 Description
# 0               FEMALE  ...  Sex of respondent (0 if male, 1 if female)
# 1                 MALE  ...  Sex of respondent (1 if male, 0 if female)
# 2                  NaN  ...                                         NaN
# 3           Ethnicity:  ...                                         NaN
# 4             ETHBLACK  ...                                       Black
# ..                 ...  ...                                         ...
# 117              URBAN  ...                     Living in an urban area
# 118              REGNE  ...                    Census region North east
# 119              REGNC  ...                 Census region North central
# 120               REGW  ...                          Census region West
# 121               REGS  ...                         Census region South
#
# [122 rows x 3 columns]

# %% [markdown]
# # Preliminary Data Exploration 🔎
#
# **Challenge**
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_data.shape
# Out:
# (2000, 96)

# %%
df_data.columns
# Out:
# Index(['ID', 'EARNINGS', 'S', 'EXP', 'FEMALE', 'MALE', 'BYEAR', 'AGE',
#        'AGEMBTH', 'HHINC97', 'POVRAT97', 'HHBMBF', 'HHBMOF', 'HHOMBF',
#        'HHBMONLY', 'HHBFONLY', 'HHOTHER', 'MSA97NO', 'MSA97NCC', 'MSA97CC',
#        'MSA97NK', 'ETHBLACK', 'ETHHISP', 'ETHWHITE', 'EDUCPROF', 'EDUCPHD',
#        'EDUCMAST', 'EDUCBA', 'EDUCAA', 'EDUCHSD', 'EDUCGED', 'EDUCDO',
#        'PRMONM', 'PRMONF', 'PRMSTYUN', 'PRMSTYPE', 'PRMSTYAN', 'PRMSTYAE',
#        'PRFSTYUN', 'PRFSTYPE', 'PRFSTYAN', 'PRFSTYAE', 'SINGLE', 'MARRIED',
#        'COHABIT', 'OTHSING', 'FAITHN', 'FAITHP', 'FAITHC', 'FAITHJ', 'FAITHO',
#        'FAITHM', 'ASVABAR', 'ASVABWK', 'ASVABPC', 'ASVABMK', 'ASVABNO',
#        'ASVABCS', 'ASVABC', 'ASVABC4', 'VERBAL', 'ASVABMV', 'HEIGHT',
#        'WEIGHT04', 'WEIGHT11', 'SF', 'SM', 'SFR', 'SMR', 'SIBLINGS', 'REG97NE',
#        'REG97NC', 'REG97S', 'REG97W', 'RS97RURL', 'RS97URBN', 'RS97UNKN',
#        'JOBS', 'HOURS', 'TENURE', 'CATGOV', 'CATPRI', 'CATNPO', 'CATMIS',
# ...

# %%
df_data.isna()
# Out:
#          ID  EARNINGS      S    EXP  ...  MSA11NCC  MSA11CC  MSA11NK  MSA11NIC
# 0     False     False  False  False  ...     False    False    False     False
# 1     False     False  False  False  ...     False    False    False     False
# 2     False     False  False  False  ...     False    False    False     False
# 3     False     False  False  False  ...     False    False    False     False
# 4     False     False  False  False  ...     False    False    False     False
# ...     ...       ...    ...    ...  ...       ...      ...      ...       ...
# 1995  False     False  False  False  ...     False    False    False     False
# 1996  False     False  False  False  ...     False    False    False     False
# 1997  False     False  False  False  ...     False    False    False     False
# 1998  False     False  False  False  ...     False    False    False     False
# 1999  False     False  False  False  ...     False    False    False     False
#
# ...

# %%
df_data = df_data.replace(np.nan, 0)

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Find and remove any duplicate rows.

# %%
duplicate = df_data[df_data.duplicated()]
duplicate
# Out:
#         ID  EARNINGS   S   EXP  ...  MSA11NCC  MSA11CC  MSA11NK  MSA11NIC
# 1000  4693     14.50  12  7.25  ...         1        0        0         0
# 1004  4827     38.48  16  8.50  ...         1        0        0         0
# 1006  4176      4.29  16  2.04  ...         1        0        0         0
# 1012  3256     10.00  12  8.02  ...         1        0        0         0
# 1015  4600     52.00  17  9.08  ...         0        1        0         0
# ...    ...       ...  ..   ...  ...       ...      ...      ...       ...
# 1993  2740     14.00  12 12.44  ...         1        0        0         0
# 1996  1119     14.83  18  1.92  ...         1        0        0         0
# 1997  3561     35.88  18  2.67  ...         0        1        0         0
# 1998  5980     25.48  16  4.71  ...         1        0        0         0
# 1999  6221     13.33  14  6.48  ...         1        0        0         0
#
# [513 rows x 96 columns]

# %%
df_data = df_data.drop_duplicates()

# %% [markdown]
# ## Descriptive Statistics

# %%
df_data.describe()
# Out:
#             ID  EARNINGS        S  ...  MSA11CC  MSA11NK  MSA11NIC
# count 1,487.00  1,487.00 1,487.00  ... 1,487.00 1,487.00  1,487.00
# mean  3,547.13     18.81    14.56  ...     0.41     0.00      0.00
# std   2,009.84     12.00     2.77  ...     0.49     0.04      0.00
# min       1.00      2.00     6.00  ...     0.00     0.00      0.00
# 25%   1,888.00     11.41    12.00  ...     0.00     0.00      0.00
# 50%   3,474.00     15.75    15.00  ...     0.00     0.00      0.00
# 75%   5,160.50     22.60    16.00  ...     1.00     0.00      0.00
# max   8,980.00    132.89    20.00  ...     1.00     1.00      0.00
#
# [8 rows x 96 columns]

# %% [markdown]
# ## Visualise the Features

# %% [markdown]
# # Earnings

# %%
sns.displot(df_data['EARNINGS'], 
            bins=50, 
            aspect=2,
            kde=True, 
            color='#2196f3')

plt.title(f'Average Earning is : ${(1000*df_data.EARNINGS.mean()):.6}')
plt.xlabel('Earnings in 000s')
plt.ylabel('Nr. of Homes')

plt.show()

# %% [markdown]
# # Split Training & Test Dataset
#
# We *can't* use all the entries in our dataset to train our model. Keep 20% of the data for later as a testing dataset (out-of-sample data).

# %%
target = df_data['EARNINGS']
features = df_data.drop('EARNINGS', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, 
                                                    target, 
                                                    test_size=0.2, 
                                                    random_state=10)

# %%
# % of training set
train_pct = 100*len(X_train)/len(features)
print(f'Training data is {train_pct:.3}% of the total data.')

# % of test data set
test_pct = 100*X_test.shape[0]/features.shape[0]
print(f'Test data makes up the remaining {test_pct:0.3}%.')
# Out:
# Training data is 80.0% of the total data.
# Test data makes up the remaining 20.0%.

# %% [markdown]
# # Simple Linear Regression
#
# Only use the years of schooling to predict earnings. Use sklearn to run the regression on the training dataset. How high is the r-squared for the regression on the training data?

# %%
new_target = np.log(df_data['S'])
features = df_data.drop('S', axis=1)

X_train, X_test, log_y_train, log_y_test = train_test_split(features, 
                                                    new_target, 
                                                    test_size=0.2, 
                                                    random_state=10)

log_regr = LinearRegression()
log_regr.fit(X_train, log_y_train)
log_rsquared = log_regr.score(X_train, log_y_train)

log_predictions = log_regr.predict(X_train)
log_residuals = (log_y_train - log_predictions)

print(f'Training data r-squared: {log_rsquared:.2}')
# Out:
# Training data r-squared: 0.85

# %% [markdown]
# ### Evaluate the Coefficients of the Model
#
# Here we do a sense check on our regression coefficients. The first thing to look for is if the coefficients have the expected sign (positive or negative).
#
# Interpret the regression. How many extra dollars can one expect to earn for an additional year of schooling?

# %%
df_coef = pd.DataFrame(data=log_regr.coef_, index=X_train.columns, columns=['coef'])
df_coef
# Out:
#           coef
# ID       -0.00
# EARNINGS  0.00
# EXP      -0.02
# FEMALE    0.01
# MALE     -0.01
# ...        ...
# MSA11NO  -0.01
# MSA11NCC -0.00
# MSA11CC  -0.00
# MSA11NK   0.02
# MSA11NIC  0.00
#
# [95 rows x 1 columns]

# %% [markdown]
# ### Analyse the Estimated Values & Regression Residuals
#
# How good our regression is also depends on the residuals - the difference between the model's predictions ( 𝑦̂ 𝑖 ) and the true values ( 𝑦𝑖 ) inside y_train. Do you see any patterns in the distribution of the residuals?

# %%
predicted_vals = log_regr.predict(X_train)
residuals = (y_train - predicted_vals)

# %%
# Graph of Actual vs. Predicted Log Earnings
plt.scatter(x=log_y_train, y=log_predictions, c='navy', alpha=0.6)
plt.plot(log_y_train, log_y_train, color='cyan')
plt.title(f'Actual vs Predicted Earnings: $y _i$ vs $\hat y_i$ (R-Squared {log_rsquared:.2})', fontsize=17)
plt.xlabel('Actual Earnings $y _i$', fontsize=14)
plt.ylabel('Prediced Earnings $\hat y _i$', fontsize=14)
plt.show()

# Original Regression of Actual vs. Predicted Earnings
plt.scatter(x=y_train, y=predicted_vals, c='indigo', alpha=0.6)
plt.plot(y_train, y_train, color='cyan')
plt.title(f'Original Actual vs Predicted Earnings: $y _i$ vs $\hat y_i$ (R-Squared {log_rsquared:.3})', fontsize=17)
plt.xlabel('Actual Earnings 000s $y _i$', fontsize=14)
plt.ylabel('Prediced Earnings 000s $\hat y _i$', fontsize=14)
plt.show()

# Residuals vs Predicted values (Log prices)
plt.scatter(x=log_predictions, y=log_residuals, c='navy', alpha=0.6)
plt.title('Residuals vs Fitted Values for Earnings', fontsize=17)
plt.xlabel('Predicted Earnings $\hat y _i$', fontsize=14)
plt.ylabel('Residuals', fontsize=14)
plt.show()

# Residuals vs Predicted values
plt.scatter(x=predicted_vals, y=residuals, c='indigo', alpha=0.6)
plt.title('Original Residuals vs Fitted Values', fontsize=17)
plt.xlabel('Predicted Earnings $\hat y _i$', fontsize=14)
plt.ylabel('Residuals', fontsize=14)
plt.show()

# %% [markdown]
# # Multivariable Regression
#
# Now use both years of schooling and the years work experience to predict earnings. How high is the r-squared for the regression on the training data?

# %%
X = df_data[['S','EXP']] 
Y = df_data['EARNINGS']
 
regr = LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -13.197346174266947
# Coefficients:
#  [1.77384834 0.92277133]

# %%
rsquared = regr.score(X, Y)

predictions = regr.predict(X)
residuals = (Y - predictions)

print(f'Training data r-squared: {rsquared:.2}')
# Out:
# Training data r-squared: 0.11

# %% [markdown]
# ### Evaluate the Coefficients of the Model

# %%
df_coeff = pd.DataFrame(data=regr.coef_, index=X.columns, columns=['coef'])
df_coeff
# Out:
#      coef
# S    1.77
# EXP  0.92

# %% [markdown]
# ### Analyse the Estimated Values & Regression Residuals

# %%
est_vals = regr.predict(X)
resids = (Y - est_vals)

# %% [markdown]
# # Use Your Model to Make a Prediction
#
# How much can someone with a bachelors degree (12 + 4) years of schooling and 5 years work experience expect to earn in 2011?

# %%
new_yearos = 16
new_exp = 5
Prediction_result  = ('Predicted Earnings: ', regr.predict([[new_yearos, new_exp]]))
print(f'expected earnings in 16 years of schooling and 5 years of experience is : {Prediction_result}')
# Out:
# expected earnings in 16 years of schooling and 5 years of experience is : ('Predicted Earnings: ', array([19.79808385]))
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
